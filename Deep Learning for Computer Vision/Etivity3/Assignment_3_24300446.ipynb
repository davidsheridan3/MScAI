# %% [markdown]
# # Assignment 3: Class Activation Map
# In this assignment we will use the [Class Activation Mapping Technique](http://cnnlocalization.csail.mit.edu/Zhou_Learning_Deep_Features_CVPR_2016_paper.pdf) to demonstrate that object specific spatial information is available in pre-trained image classification networks.
#
# ## Introduction:
# The final output convolution layers of a trained image classification network contain detailed semantic information about the input image. These feature maps, although low resolution (e.g. 7 x 7) also contain spatial information about the location of the primary object in the image. In the class activation mapping technique we wish to extract this spatial information pertaining to the identified class and overlay this activation on the input image as shown in the figure below.
#
# ![](https://github.com/tonyscan6003/etivities/blob/main/cam_img.JPG?raw=true)
#
# * Try to understand the algorithm and plan out the steps required before starting to code.
# * The Resnet 50 model has been imported and outputs the last convolution layer and the logits (output of classifier)
# * You can display your final results on a 4 x 4 plot.
#  * Skeleton code is provided along with a function to unormalise the dataloader images for display.
#  * The activation map using a heat map color scheme can be overlaid on the images using matplotlib "alpha" which sets the transparancy of the image e.g. `plt.imshow(class_act_map,cmap=plt.cm.jet,alpha=0.4)`

# %% [markdown]
# ## HouseKeeping
#   Import Packages, set batch size and Size of Images input to network.

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import time
import os
import numpy as np
import glob
import random
import torch
import torch.nn.functional as F
from torch import nn
from torchvision import datasets, models
from torchvision import utils
from torchvision.transforms import ToTensor, v2, Pad, Grayscale
from torchvision.models.feature_extraction import get_graph_node_names
from torchvision.models.feature_extraction import create_feature_extractor
import matplotlib.pyplot as plt
import torchvision.transforms as transforms

import matplotlib.pyplot as plt
from IPython.display import clear_output
from torchvision.models import ResNet50_Weights, resnet50
from torchvision.models.feature_extraction import create_feature_extractor
from torchinfo import summary

# %%
# !pip install torchinfo
# !pip install torchmetrics
# Out:
# Requirement already satisfied: torchinfo in c:\users\david.sheridan\appdata\local\anaconda3\lib\site-packages (1.8.0)
# Requirement already satisfied: torchmetrics in c:\users\david.sheridan\appdata\local\anaconda3\lib\site-packages (1.8.2)
# Requirement already satisfied: numpy>1.20.0 in c:\users\david.sheridan\appdata\local\anaconda3\lib\site-packages (from torchmetrics) (1.26.4)
# Requirement already satisfied: packaging>17.1 in c:\users\david.sheridan\appdata\local\anaconda3\lib\site-packages (from torchmetrics) (23.2)
# Requirement already satisfied: torch>=2.0.0 in c:\users\david.sheridan\appdata\local\anaconda3\lib\site-packages (from torchmetrics) (2.7.1+cu118)
# Requirement already satisfied: lightning-utilities>=0.8.0 in c:\users\david.sheridan\appdata\local\anaconda3\lib\site-packages (from torchmetrics) (0.15.2)
# Requirement already satisfied: setuptools in c:\users\david.sheridan\appdata\local\anaconda3\lib\site-packages (from lightning-utilities>=0.8.0->torchmetrics) (69.5.1)
# Requirement already satisfied: typing_extensions in c:\users\david.sheridan\appdata\local\anaconda3\lib\site-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.15.0)
# Requirement already satisfied: filelock in c:\users\david.sheridan\appdata\local\anaconda3\lib\site-packages (from torch>=2.0.0->torchmetrics) (3.13.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\david.sheridan\appdata\local\anaconda3\lib\site-packages (from torch>=2.0.0->torchmetrics) (1.14.0)
# Requirement already satisfied: networkx in c:\users\david.sheridan\appdata\local\anaconda3\lib\site-packages (from torch>=2.0.0->torchmetrics) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\david.sheridan\appdata\local\anaconda3\lib\site-packages (from torch>=2.0.0->torchmetrics) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\david.sheridan\appdata\local\anaconda3\lib\site-packages (from torch>=2.0.0->torchmetrics) (2024.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\david.sheridan\appdata\local\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=2.0.0->torchmetrics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\david.sheridan\appdata\local\anaconda3\lib\site-packages (from jinja2->torch>=2.0.0->torchmetrics) (2.1.3)

# %%
# Global Variables
HW_trg =224

# %% [markdown]
# ## Import Dataset
#
#  For this notebook we will use the pytorch [ImageNett dataset](https://pytorch.org/vision/main/generated/torchvision.datasets.Imagenette.html) which contains a sub-set of the ImageNet test dataset with only 10 examples per class. This will be sufficient to demonstrate the Class Activation Mapping algorithm.
#
# The transform is setup without data augmentation and with the required normalisation for the ResNet50 model.

# %%
transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])
imagenet_data = datasets.Imagenette('/root/INET',download=False,transform=transform)
data_loader = torch.utils.data.DataLoader(imagenet_data,
                                          batch_size=1,
                                          shuffle=True)

# %% [markdown]
# Plot a test image from the dataset. The image must be unnormalised and output in the correct form [H,W,C] for display by plt.imshow using `<unnormalise image function>`. (You can re-use this function later to unnormalise images that you will overlay the class activation maps onto.)

# %%
imagenette_dict={0:'Tench Fish',217:'English Springer',482:'Casette Player',
                491:'Chain Saw',497:'Church',566:'French Horn',
                 569:'Grabage Truck',571:'Gas Pump',574:'Golfball',
                 662:'Modem', 701:'Parachute',864:'Tow Truck', 867:'Trailer Truck'}
mean = [0.485, 0.456, 0.406]  # Example mean used for normalization
std = [0.229, 0.224, 0.225]   # Example std used for normalization

def unnormalize_image(image, mean, std):
    """
    Unnormalize a PyTorch image tensor.

    Args:
        image (torch.Tensor): The normalized image tensor of shape [C, H, W].
        mean (list or tuple): The mean used for normalization.
        std (list or tuple): The standard deviation used for normalization.

    Returns:
        torch.Tensor: The unnormalized image tensor.
    """
    # Remove the batch dimension
    image = image.squeeze(0)

    # Check if the image is in the shape [C, H, W]
    if image.dim() == 3:
        # Unnormalize the image
        for t, m, s in zip(image, mean, std):
            t.mul_(s).add_(m)
    else:
        raise ValueError("Expected image tensor of shape [C, H, W]")

    # Convert from [C, x, y] to [x, y, C]
    image = image.permute(1, 2, 0)

    return image

# %%
# Verity Dataloader & Image
dataiter = iter(data_loader)
z = next(dataiter)
print(np.shape(z[0]))

img=unnormalize_image(z[0],mean,std)
plt.imshow(img)
# Out:
# torch.Size([1, 3, 224, 224])

# %% [markdown]
# # Import Model
#
# This assignment can be completed with CPU runtime as only inference from the model is required. The ResNet50 model is imported for this Assignment. As detailed in the paper a global average pooling layer conected to the classifier layer is required to work. The Resnet50 model satisfies this requirement (without needing modification & retraining)

# %%
# Get cpu, gpu or mps device for training.
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cpu device

# %% [markdown]
# ResNet50 Model is loaded & modified with [create_feature_extraction](https://pytorch.org/vision/stable/feature_extraction.html) to allow output of both logits and feature maps

# %%
#Loading Model & Feature Extractor
weights = ResNet50_Weights.IMAGENET1K_V2
resnet50 = models.resnet50(weights=weights)

#Extracting feature maps from last conv layer and final fc logits
return_nodes = {'layer4.2.conv3': 'features', 'fc': 'logits'}
model = create_feature_extractor(resnet50, return_nodes=return_nodes).to(device)
model.eval()

#Loading classifier weights
fc_weights = model.state_dict()['fc.weight'].to(device)

#Imagenet class names for full top-5 support
imagenet_labels = weights.meta['categories']

# %%
# Plot Model Summary
summary(model, input_size=(1, 3, 224, 224))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ResNet                                   [1, 1000]                 --
# ├─Conv2d: 1-1                            [1, 64, 112, 112]         9,408
# ├─BatchNorm2d: 1-2                       [1, 64, 112, 112]         128
# ├─ReLU: 1-3                              [1, 64, 112, 112]         --
# ├─MaxPool2d: 1-4                         [1, 64, 56, 56]           --
# ├─Module: 1-5                            --                        --
# │    └─Module: 2-1                       --                        --
# │    │    └─Conv2d: 3-1                  [1, 64, 56, 56]           4,096
# │    │    └─BatchNorm2d: 3-2             [1, 64, 56, 56]           128
# │    │    └─ReLU: 3-3                    [1, 64, 56, 56]           --
# │    │    └─Conv2d: 3-4                  [1, 64, 56, 56]           36,864
# │    │    └─BatchNorm2d: 3-5             [1, 64, 56, 56]           128
# │    │    └─ReLU: 3-6                    [1, 64, 56, 56]           --
# │    │    └─Conv2d: 3-7                  [1, 256, 56, 56]          16,384
# │    │    └─BatchNorm2d: 3-8             [1, 256, 56, 56]          512
# │    │    └─Module: 3-9                  --                        16,896
# │    │    └─ReLU: 3-10                   [1, 256, 56, 56]          --
# │    └─Module: 2-2                       --                        --
# │    │    └─Conv2d: 3-11                 [1, 64, 56, 56]           16,384
# │    │    └─BatchNorm2d: 3-12            [1, 64, 56, 56]           128
# │    │    └─ReLU: 3-13                   [1, 64, 56, 56]           --
# │    │    └─Conv2d: 3-14                 [1, 64, 56, 56]           36,864
# │    │    └─BatchNorm2d: 3-15            [1, 64, 56, 56]           128
# │    │    └─ReLU: 3-16                   [1, 64, 56, 56]           --
# │    │    └─Conv2d: 3-17                 [1, 256, 56, 56]          16,384
# │    │    └─BatchNorm2d: 3-18            [1, 256, 56, 56]          512
# │    │    └─ReLU: 3-19                   [1, 256, 56, 56]          --
# │    └─Module: 2-3                       --                        --
# │    │    └─Conv2d: 3-20                 [1, 64, 56, 56]           16,384
# │    │    └─BatchNorm2d: 3-21            [1, 64, 56, 56]           128
# │    │    └─ReLU: 3-22                   [1, 64, 56, 56]           --
# │    │    └─Conv2d: 3-23                 [1, 64, 56, 56]           36,864
# │    │    └─BatchNorm2d: 3-24            [1, 64, 56, 56]           128
# │    │    └─ReLU: 3-25                   [1, 64, 56, 56]           --
# │    │    └─Conv2d: 3-26                 [1, 256, 56, 56]          16,384
# │    │    └─BatchNorm2d: 3-27            [1, 256, 56, 56]          512
# │    │    └─ReLU: 3-28                   [1, 256, 56, 56]          --
# ├─Module: 1-6                            --                        --
# │    └─Module: 2-4                       --                        --
# │    │    └─Conv2d: 3-29                 [1, 128, 56, 56]          32,768
# │    │    └─BatchNorm2d: 3-30            [1, 128, 56, 56]          256
# │    │    └─ReLU: 3-31                   [1, 128, 56, 56]          --
# │    │    └─Conv2d: 3-32                 [1, 128, 28, 28]          147,456
# │    │    └─BatchNorm2d: 3-33            [1, 128, 28, 28]          256
# │    │    └─ReLU: 3-34                   [1, 128, 28, 28]          --
# │    │    └─Conv2d: 3-35                 [1, 512, 28, 28]          65,536
# │    │    └─BatchNorm2d: 3-36            [1, 512, 28, 28]          1,024
# │    │    └─Module: 3-37                 --                        132,096
# │    │    └─ReLU: 3-38                   [1, 512, 28, 28]          --
# │    └─Module: 2-5                       --                        --
# │    │    └─Conv2d: 3-39                 [1, 128, 28, 28]          65,536
# │    │    └─BatchNorm2d: 3-40            [1, 128, 28, 28]          256
# │    │    └─ReLU: 3-41                   [1, 128, 28, 28]          --
# │    │    └─Conv2d: 3-42                 [1, 128, 28, 28]          147,456
# │    │    └─BatchNorm2d: 3-43            [1, 128, 28, 28]          256
# │    │    └─ReLU: 3-44                   [1, 128, 28, 28]          --
# │    │    └─Conv2d: 3-45                 [1, 512, 28, 28]          65,536
# │    │    └─BatchNorm2d: 3-46            [1, 512, 28, 28]          1,024
# │    │    └─ReLU: 3-47                   [1, 512, 28, 28]          --
# │    └─Module: 2-6                       --                        --
# │    │    └─Conv2d: 3-48                 [1, 128, 28, 28]          65,536
# │    │    └─BatchNorm2d: 3-49            [1, 128, 28, 28]          256
# │    │    └─ReLU: 3-50                   [1, 128, 28, 28]          --
# │    │    └─Conv2d: 3-51                 [1, 128, 28, 28]          147,456
# │    │    └─BatchNorm2d: 3-52            [1, 128, 28, 28]          256
# │    │    └─ReLU: 3-53                   [1, 128, 28, 28]          --
# │    │    └─Conv2d: 3-54                 [1, 512, 28, 28]          65,536
# │    │    └─BatchNorm2d: 3-55            [1, 512, 28, 28]          1,024
# │    │    └─ReLU: 3-56                   [1, 512, 28, 28]          --
# │    └─Module: 2-7                       --                        --
# │    │    └─Conv2d: 3-57                 [1, 128, 28, 28]          65,536
# │    │    └─BatchNorm2d: 3-58            [1, 128, 28, 28]          256
# │    │    └─ReLU: 3-59                   [1, 128, 28, 28]          --
# │    │    └─Conv2d: 3-60                 [1, 128, 28, 28]          147,456
# │    │    └─BatchNorm2d: 3-61            [1, 128, 28, 28]          256
# │    │    └─ReLU: 3-62                   [1, 128, 28, 28]          --
# │    │    └─Conv2d: 3-63                 [1, 512, 28, 28]          65,536
# │    │    └─BatchNorm2d: 3-64            [1, 512, 28, 28]          1,024
# │    │    └─ReLU: 3-65                   [1, 512, 28, 28]          --
# ├─Module: 1-7                            --                        --
# │    └─Module: 2-8                       --                        --
# │    │    └─Conv2d: 3-66                 [1, 256, 28, 28]          131,072
# │    │    └─BatchNorm2d: 3-67            [1, 256, 28, 28]          512
# │    │    └─ReLU: 3-68                   [1, 256, 28, 28]          --
# │    │    └─Conv2d: 3-69                 [1, 256, 14, 14]          589,824
# │    │    └─BatchNorm2d: 3-70            [1, 256, 14, 14]          512
# │    │    └─ReLU: 3-71                   [1, 256, 14, 14]          --
# │    │    └─Conv2d: 3-72                 [1, 1024, 14, 14]         262,144
# │    │    └─BatchNorm2d: 3-73            [1, 1024, 14, 14]         2,048
# │    │    └─Module: 3-74                 --                        526,336
# │    │    └─ReLU: 3-75                   [1, 1024, 14, 14]         --
# │    └─Module: 2-9                       --                        --
# │    │    └─Conv2d: 3-76                 [1, 256, 14, 14]          262,144
# │    │    └─BatchNorm2d: 3-77            [1, 256, 14, 14]          512
# │    │    └─ReLU: 3-78                   [1, 256, 14, 14]          --
# │    │    └─Conv2d: 3-79                 [1, 256, 14, 14]          589,824
# │    │    └─BatchNorm2d: 3-80            [1, 256, 14, 14]          512
# │    │    └─ReLU: 3-81                   [1, 256, 14, 14]          --
# │    │    └─Conv2d: 3-82                 [1, 1024, 14, 14]         262,144
# │    │    └─BatchNorm2d: 3-83            [1, 1024, 14, 14]         2,048
# │    │    └─ReLU: 3-84                   [1, 1024, 14, 14]         --
# │    └─Module: 2-10                      --                        --
# │    │    └─Conv2d: 3-85                 [1, 256, 14, 14]          262,144
# │    │    └─BatchNorm2d: 3-86            [1, 256, 14, 14]          512
# │    │    └─ReLU: 3-87                   [1, 256, 14, 14]          --
# │    │    └─Conv2d: 3-88                 [1, 256, 14, 14]          589,824
# │    │    └─BatchNorm2d: 3-89            [1, 256, 14, 14]          512
# │    │    └─ReLU: 3-90                   [1, 256, 14, 14]          --
# │    │    └─Conv2d: 3-91                 [1, 1024, 14, 14]         262,144
# │    │    └─BatchNorm2d: 3-92            [1, 1024, 14, 14]         2,048
# │    │    └─ReLU: 3-93                   [1, 1024, 14, 14]         --
# │    └─Module: 2-11                      --                        --
# │    │    └─Conv2d: 3-94                 [1, 256, 14, 14]          262,144
# │    │    └─BatchNorm2d: 3-95            [1, 256, 14, 14]          512
# │    │    └─ReLU: 3-96                   [1, 256, 14, 14]          --
# │    │    └─Conv2d: 3-97                 [1, 256, 14, 14]          589,824
# │    │    └─BatchNorm2d: 3-98            [1, 256, 14, 14]          512
# │    │    └─ReLU: 3-99                   [1, 256, 14, 14]          --
# │    │    └─Conv2d: 3-100                [1, 1024, 14, 14]         262,144
# │    │    └─BatchNorm2d: 3-101           [1, 1024, 14, 14]         2,048
# │    │    └─ReLU: 3-102                  [1, 1024, 14, 14]         --
# │    └─Module: 2-12                      --                        --
# │    │    └─Conv2d: 3-103                [1, 256, 14, 14]          262,144
# │    │    └─BatchNorm2d: 3-104           [1, 256, 14, 14]          512
# │    │    └─ReLU: 3-105                  [1, 256, 14, 14]          --
# │    │    └─Conv2d: 3-106                [1, 256, 14, 14]          589,824
# │    │    └─BatchNorm2d: 3-107           [1, 256, 14, 14]          512
# │    │    └─ReLU: 3-108                  [1, 256, 14, 14]          --
# │    │    └─Conv2d: 3-109                [1, 1024, 14, 14]         262,144
# │    │    └─BatchNorm2d: 3-110           [1, 1024, 14, 14]         2,048
# │    │    └─ReLU: 3-111                  [1, 1024, 14, 14]         --
# │    └─Module: 2-13                      --                        --
# │    │    └─Conv2d: 3-112                [1, 256, 14, 14]          262,144
# │    │    └─BatchNorm2d: 3-113           [1, 256, 14, 14]          512
# │    │    └─ReLU: 3-114                  [1, 256, 14, 14]          --
# │    │    └─Conv2d: 3-115                [1, 256, 14, 14]          589,824
# │    │    └─BatchNorm2d: 3-116           [1, 256, 14, 14]          512
# │    │    └─ReLU: 3-117                  [1, 256, 14, 14]          --
# │    │    └─Conv2d: 3-118                [1, 1024, 14, 14]         262,144
# │    │    └─BatchNorm2d: 3-119           [1, 1024, 14, 14]         2,048
# │    │    └─ReLU: 3-120                  [1, 1024, 14, 14]         --
# ├─Module: 1-8                            --                        --
# │    └─Module: 2-14                      --                        --
# │    │    └─Conv2d: 3-121                [1, 512, 14, 14]          524,288
# │    │    └─BatchNorm2d: 3-122           [1, 512, 14, 14]          1,024
# │    │    └─ReLU: 3-123                  [1, 512, 14, 14]          --
# │    │    └─Conv2d: 3-124                [1, 512, 7, 7]            2,359,296
# │    │    └─BatchNorm2d: 3-125           [1, 512, 7, 7]            1,024
# │    │    └─ReLU: 3-126                  [1, 512, 7, 7]            --
# │    │    └─Conv2d: 3-127                [1, 2048, 7, 7]           1,048,576
# │    │    └─BatchNorm2d: 3-128           [1, 2048, 7, 7]           4,096
# │    │    └─Module: 3-129                --                        2,101,248
# │    │    └─ReLU: 3-130                  [1, 2048, 7, 7]           --
# │    └─Module: 2-15                      --                        --
# │    │    └─Conv2d: 3-131                [1, 512, 7, 7]            1,048,576
# │    │    └─BatchNorm2d: 3-132           [1, 512, 7, 7]            1,024
# │    │    └─ReLU: 3-133                  [1, 512, 7, 7]            --
# │    │    └─Conv2d: 3-134                [1, 512, 7, 7]            2,359,296
# │    │    └─BatchNorm2d: 3-135           [1, 512, 7, 7]            1,024
# │    │    └─ReLU: 3-136                  [1, 512, 7, 7]            --
# │    │    └─Conv2d: 3-137                [1, 2048, 7, 7]           1,048,576
# │    │    └─BatchNorm2d: 3-138           [1, 2048, 7, 7]           4,096
# │    │    └─ReLU: 3-139                  [1, 2048, 7, 7]           --
# │    └─Module: 2-16                      --                        --
# │    │    └─Conv2d: 3-140                [1, 512, 7, 7]            1,048,576
# │    │    └─BatchNorm2d: 3-141           [1, 512, 7, 7]            1,024
# │    │    └─ReLU: 3-142                  [1, 512, 7, 7]            --
# │    │    └─Conv2d: 3-143                [1, 512, 7, 7]            2,359,296
# │    │    └─BatchNorm2d: 3-144           [1, 512, 7, 7]            1,024
# │    │    └─ReLU: 3-145                  [1, 512, 7, 7]            --
# │    │    └─Conv2d: 3-146                [1, 2048, 7, 7]           1,048,576
# │    │    └─BatchNorm2d: 3-147           [1, 2048, 7, 7]           4,096
# │    │    └─ReLU: 3-148                  [1, 2048, 7, 7]           --
# ├─AdaptiveAvgPool2d: 1-9                 [1, 2048, 1, 1]           --
# ├─Linear: 1-10                           [1, 1000]                 2,049,000
# ==========================================================================================
# Total params: 25,557,032
# Trainable params: 25,557,032
# Non-trainable params: 0
# Total mult-adds (G): 4.09
# ==========================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 177.83
# Params size (MB): 102.23
# Estimated Total Size (MB): 280.66
# ==========================================================================================

# %% [markdown]
# Test Passing data through model & verify outputs.

# %%
#pass data through model
print([(k, v.shape) for k, v in out.items()])
# Out:
# [('features', torch.Size([1, 2048, 7, 7])), ('logits', torch.Size([1, 1000]))]

# %% [markdown]
# Obtain weights of classifier layer of model from state dictionary

# %%
sd = model.state_dict()
print(sd.keys())
print(np.shape((sd['fc.weight'])))
# Out:
# odict_keys(['conv1.weight', 'bn1.weight', 'bn1.bias', 'bn1.running_mean', 'bn1.running_var', 'bn1.num_batches_tracked', 'layer1.0.conv1.weight', 'layer1.0.bn1.weight', 'layer1.0.bn1.bias', 'layer1.0.bn1.running_mean', 'layer1.0.bn1.running_var', 'layer1.0.bn1.num_batches_tracked', 'layer1.0.conv2.weight', 'layer1.0.bn2.weight', 'layer1.0.bn2.bias', 'layer1.0.bn2.running_mean', 'layer1.0.bn2.running_var', 'layer1.0.bn2.num_batches_tracked', 'layer1.0.conv3.weight', 'layer1.0.bn3.weight', 'layer1.0.bn3.bias', 'layer1.0.bn3.running_mean', 'layer1.0.bn3.running_var', 'layer1.0.bn3.num_batches_tracked', 'layer1.0.downsample.0.weight', 'layer1.0.downsample.1.weight', 'layer1.0.downsample.1.bias', 'layer1.0.downsample.1.running_mean', 'layer1.0.downsample.1.running_var', 'layer1.0.downsample.1.num_batches_tracked', 'layer1.1.conv1.weight', 'layer1.1.bn1.weight', 'layer1.1.bn1.bias', 'layer1.1.bn1.running_mean', 'layer1.1.bn1.running_var', 'layer1.1.bn1.num_batches_tracked', 'layer1.1.conv2.weight', 'layer1.1.bn2.weight', 'layer1.1.bn2.bias', 'layer1.1.bn2.running_mean', 'layer1.1.bn2.running_var', 'layer1.1.bn2.num_batches_tracked', 'layer1.1.conv3.weight', 'layer1.1.bn3.weight', 'layer1.1.bn3.bias', 'layer1.1.bn3.running_mean', 'layer1.1.bn3.running_var', 'layer1.1.bn3.num_batches_tracked', 'layer1.2.conv1.weight', 'layer1.2.bn1.weight', 'layer1.2.bn1.bias', 'layer1.2.bn1.running_mean', 'layer1.2.bn1.running_var', 'layer1.2.bn1.num_batches_tracked', 'layer1.2.conv2.weight', 'layer1.2.bn2.weight', 'layer1.2.bn2.bias', 'layer1.2.bn2.running_mean', 'layer1.2.bn2.running_var', 'layer1.2.bn2.num_batches_tracked', 'layer1.2.conv3.weight', 'layer1.2.bn3.weight', 'layer1.2.bn3.bias', 'layer1.2.bn3.running_mean', 'layer1.2.bn3.running_var', 'layer1.2.bn3.num_batches_tracked', 'layer2.0.conv1.weight', 'layer2.0.bn1.weight', 'layer2.0.bn1.bias', 'layer2.0.bn1.running_mean', 'layer2.0.bn1.running_var', 'layer2.0.bn1.num_batches_tracked', 'layer2.0.conv2.weight', 'layer2.0.bn2.weight', 'layer2.0.bn2.bias', 'layer2.0.bn2.running_mean', 'layer2.0.bn2.running_var', 'layer2.0.bn2.num_batches_tracked', 'layer2.0.conv3.weight', 'layer2.0.bn3.weight', 'layer2.0.bn3.bias', 'layer2.0.bn3.running_mean', 'layer2.0.bn3.running_var', 'layer2.0.bn3.num_batches_tracked', 'layer2.0.downsample.0.weight', 'layer2.0.downsample.1.weight', 'layer2.0.downsample.1.bias', 'layer2.0.downsample.1.running_mean', 'layer2.0.downsample.1.running_var', 'layer2.0.downsample.1.num_batches_tracked', 'layer2.1.conv1.weight', 'layer2.1.bn1.weight', 'layer2.1.bn1.bias', 'layer2.1.bn1.running_mean', 'layer2.1.bn1.running_var', 'layer2.1.bn1.num_batches_tracked', 'layer2.1.conv2.weight', 'layer2.1.bn2.weight', 'layer2.1.bn2.bias', 'layer2.1.bn2.running_mean', 'layer2.1.bn2.running_var', 'layer2.1.bn2.num_batches_tracked', 'layer2.1.conv3.weight', 'layer2.1.bn3.weight', 'layer2.1.bn3.bias', 'layer2.1.bn3.running_mean', 'layer2.1.bn3.running_var', 'layer2.1.bn3.num_batches_tracked', 'layer2.2.conv1.weight', 'layer2.2.bn1.weight', 'layer2.2.bn1.bias', 'layer2.2.bn1.running_mean', 'layer2.2.bn1.running_var', 'layer2.2.bn1.num_batches_tracked', 'layer2.2.conv2.weight', 'layer2.2.bn2.weight', 'layer2.2.bn2.bias', 'layer2.2.bn2.running_mean', 'layer2.2.bn2.running_var', 'layer2.2.bn2.num_batches_tracked', 'layer2.2.conv3.weight', 'layer2.2.bn3.weight', 'layer2.2.bn3.bias', 'layer2.2.bn3.running_mean', 'layer2.2.bn3.running_var', 'layer2.2.bn3.num_batches_tracked', 'layer2.3.conv1.weight', 'layer2.3.bn1.weight', 'layer2.3.bn1.bias', 'layer2.3.bn1.running_mean', 'layer2.3.bn1.running_var', 'layer2.3.bn1.num_batches_tracked', 'layer2.3.conv2.weight', 'layer2.3.bn2.weight', 'layer2.3.bn2.bias', 'layer2.3.bn2.running_mean', 'layer2.3.bn2.running_var', 'layer2.3.bn2.num_batches_tracked', 'layer2.3.conv3.weight', 'layer2.3.bn3.weight', 'layer2.3.bn3.bias', 'layer2.3.bn3.running_mean', 'layer2.3.bn3.running_var', 'layer2.3.bn3.num_batches_tracked', 'layer3.0.conv1.weight', 'layer3.0.bn1.weight', 'l ...
# torch.Size([1000, 2048])

# %%
#Helper Functions
def unnormalize_image(image_tensor):
    image = image_tensor.squeeze(0).cpu()
    for t, m, s in zip(image, mean, std):
        t.mul_(s).add_(m)
    return image.permute(1, 2, 0).clamp(0, 1)

def compute_cam(features, class_weights):
    cam = (features * class_weights).sum(dim=1, keepdim=True)
    cam = cam - cam.min()
    cam = cam / (cam.max() + 1e-6)
    return F.interpolate(cam, size=(224, 224), mode='bilinear', align_corners=False)

# %% [markdown]
# # Class Activion Mapping
# You can implement the class activation mapping algorithm in the code cell below.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Initialize Figure
fig = plt.figure(figsize=(10,10), frameon=False)


# Iterate over the dataiter to produce a few examples

# Ensure model is eval mode to disable batch normalisation during inference.
model.eval()
for i in range(10):
    #Loading one image from dataloader
    img, label = next(dataiter)
    img = img.to(device)

    #Forward pass
    with torch.no_grad():
        out = model(img)

    features = out['features'] #shape: [1, 2048, 7, 7]
    logits = out['logits'] #shape: [1, 1000]
    pred_class = logits.argmax(dim=1) #Top-1 class index

    #Getting weights for predicted class
    weights = fc_weights[pred_class].unsqueeze(2).unsqueeze(3)  #shape: [1, 2048, 1, 1]

    #Compute CAM
    cam = (weights * features).sum(dim=1, keepdim=True)
    cam = cam - cam.min()
    cam = cam / (cam.max() + 1e-6)
    cam_resized = F.interpolate(cam, size=(224, 224), mode='bilinear', align_corners=False)

    #Unnormalising image for plotting
    img_disp = unnormalize_image(img, mean, std)

    #Trying to get human-readable label (from imagenette_dict)
    def get_value(dictionary, key):
        try:
            return dictionary[key]
        except KeyError:
            return f"Class {key}"

    label_str = get_value(imagenette_dict, int(pred_class.item()))

    #N. Plotting
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    ax.title.set_text(label_str)
    ax.imshow(img_disp)
    ax.imshow(cam_resized.squeeze().cpu().numpy(), cmap=plt.cm.jet, alpha=0.4)

plt.tight_layout()
plt.show()

# %%
#Top 5 Class Activation Mapping
#Setting model to evaluation mode
model.eval()

#Creating new figure
fig_top5 = plt.figure(figsize=(16, 10), frameon=False)

#Processing 3 images
for i in range(3):
    # Get one image from the data loader
    img, label = next(dataiter)
    img = img.to(device)

    #Forward pass
    with torch.no_grad():
        out = model(img)

    features = out['features'] #[1, 2048, 7, 7]
    logits = out['logits'] #[1, 1000]

    #Getting Top-5 predicted classes and probabilities
    top5_probs, top5_classes = torch.topk(logits, 5)

    #Unnormalising image for plotting
    img_disp = unnormalize_image(img, mean, std)

    for j in range(5):
        class_idx = top5_classes[0, j]
        class_prob = top5_probs[0, j].item()

        #Getting weights for this class
        weights = fc_weights[class_idx].unsqueeze(1).unsqueeze(2)

        #Computing CAM
        cam = (weights * features).sum(dim=1, keepdim=True)
        cam = cam - cam.min()
        cam = cam / (cam.max() + 1e-6)
        cam_resized = F.interpolate(cam, size=(224, 224), mode='bilinear', align_corners=False)

        #Getting class label
        label_str = imagenet_labels[class_idx]

        #Plotting
        ax = fig_top5.add_subplot(3, 5, i * 5 + j + 1, xticks=[], yticks=[])
        ax.set_title(f"{label_str[:20]} ({class_prob:.2f})", fontsize=14)
        ax.imshow(img_disp)
        ax.imshow(cam_resized.squeeze().cpu(), cmap='jet', alpha=0.4)

plt.tight_layout()
plt.show()

# %% [markdown]
# # You may Leave a note here explaining your approach/results for the e-moderator.
#
# Please clearly identify any code blocks you have used, suggestions your have tried or ideas obtained from other students. This information may also be posted as a final reflection post in the forum.

# %% [markdown]
# For this assignment, I focused on understanding how Class Activation Mapping (CAM) works using the pre-trained ResNet50 model.
#
# Following the guidance in the notebook and resources shared in the forum, I worked step-by-step to:
# - Load and preprocess the Imagenette dataset
# - Extract the feature maps and logits using `create_feature_extractor`
# - Implement CAM by multiplying the class-specific weights with the last convolutional feature maps
# - Resize and overlay the activation maps onto the input image using matplotlib
# - Finally, visualise both Top-1 and Top-5 class activations
#
# I kept my code well-commented and beginner-friendly, especially as I found it helpful when troubleshooting things like tensor dimensions and image unnormalization.
#
# I also asked a few questions in the forum (e.g. about the Top-5 CAMs) and took inspiration from posts by others, including Miriam’s tips on debugging and dimension checks. I used `.item()` instead of `.numpy()` in one place after seeing a deprecation warning, which helped keep things clean.
#
# The CAM overlays correctly highlight the relevant object areas in the image, and the Top-5 CAMs show how the network activates for semantically similar classes.
#
# Thanks to everyone for their help and examples. This was a challenging but interesting task.
#
# David Sheridan (24300446)
