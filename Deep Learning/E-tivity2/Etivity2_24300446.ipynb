# %% [markdown]
# # E-tivity 2 Weeks 3-4
#
# * David Sheridan
#
# * 24300446

# %% [markdown]
# ## Outline
#
# This e-tivity is split into two parts. The first part <a href="#part1">**Stock Predicition**</a> is a group activity where you are tasked with predicting the stock market.
#
# The second <a href="#part2">**Sentiment Analysis**</a> is an individual task, the problem is to predict if a film review is positive or negative.

# %% [markdown]
# ### Guidelines
#
# The e-tivity is split into five tasks. The first four are "group" excersises, in that you post the solutions to Tasks 1-4 to the Group Locker. This will allow the members of your group to send you feedback (via the forums) so you can improve your submission. The final task is an individual task and together with the other tasks, should be uploaded to Brightspace.
#
# Marks will be deducted if task 5 is uploaded in contravention of instructions. Also if the the final submission is not a single notebook with tasks 1-5 and with correct identification or filename.
#
#
# Grading guidelines: the rubrics for the e-tivity are here https://learn.ul.ie/d2l/lp/rubrics/preview.d2l?ou=73310&rubricId=4446&originTool=quicklinks

# %% [markdown]
# <a id='part1'></a>
# ## Stock Prediction
#
# ### Context
#
# There is a small dataset of real stock prices for each working day from the end of 2015 to the end of 2019. There are four variables (with a time stamp), stock price, oil price, gold price and Euro to Dollar exchange. You need to predict the Stock price a day ahead from only the past values of each of the 4 variables.
#
#
# ### Tasks 1-4 (complete by Sunday Week 4)
#
# Create additional cells to complete the tasks below. These form the group exercises and you can upload your code for Tasks 1-4 to the group locker.

# %% [markdown]
# **Task 1: data preprocessing**
#
# Explain any preprocessing steps you take including but limited to reformatting and also how you have selected the training and test sets. The test set should be 20% of the whole.

# %%
#Importing Required Libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
#Loading Data
#Read CSV file, parse_dates converts Date column into datetime format, index_col sets Date as index for time-series structure
df = pd.read_csv("stock.csv", parse_dates=["Date"], index_col="Date")

# Display first rows to confirm loading
print(df.head())
# Out:
#                   Stock        Oil  EuroToDollar    Gold
# Date
# 2015-11-23  2089.409912  41.490002        0.9432  1124.7
# 2015-11-24  2084.419922  42.040001        0.9388  1131.6
# 2015-11-25  2089.300049  42.689999        0.9420  1128.4
# 2015-11-27  2088.820068  43.250000        0.9438  1114.5
# 2015-11-30  2090.949951  41.770000        0.9468  1123.9

# %%
#Ensuring chronological order
df = df.sort_index()

# %%
#Inspecting Data Structure
print("\nDataset shape:", df.shape)
print("\nMissing values:\n", df.isna().sum())
print("\nData types:\n", df.dtypes)
# Out:
# Dataset shape: (1033, 4)
#
# Missing values:
#  Stock            0
# Oil             10
# EuroToDollar    12
# Gold             0
# dtype: int64
#
# Data types:
#  Stock           float64
# Oil             float64
# EuroToDollar    float64
# Gold            float64
# dtype: object

# %%
#Scaling features
#Creating scaler object
scaler = MinMaxScaler()

#Fitting scaler and transform data
scaled_values = scaler.fit_transform(df)

#Converting back to DataFrame for readability
df_scaled = pd.DataFrame(scaled_values,
                         columns=df.columns,
                         index=df.index)

# %%
#Creating supervised learning target
#Shifting Stock column up by 1 day to create prediction target (allows model to predict tomorrow's stock value)
df_scaled["Target"] = df_scaled["Stock"].shift(-1)

#Removing final row (no future value available)
df_scaled = df_scaled.dropna()

# %%
#Train/Test split (80/20)
#Determine split index
split_index = int(len(df_scaled) * 0.8)

#First 80% used for training
train = df_scaled.iloc[:split_index]

#Last 20% used for testing
test = df_scaled.iloc[split_index:]

print("\nTraining samples:", len(train))
print("Testing samples:", len(test))

#Separate features and target
X_train = train.drop("Target", axis=1)
y_train = train["Target"]

X_test = test.drop("Target", axis=1)
y_test = test["Target"]

print("\nFeature shape:", X_train.shape)
print("Target shape:", y_train.shape)
# Out:
# Training samples: 810
# Testing samples: 203
#
# Feature shape: (810, 4)
# Target shape: (810,)

# %% [markdown]
# **Task 2: data cleaning**
#
# There are a number of missing values in the data. Clean the data so that it is suitable for use with the NN. Bare in mind that you want to retain the time coherency of the data as much as possible. Explain the steps you have taken.

# %%
#Check missing values before cleaning
print("Missing values before cleaning:\n")
print(df.isna().sum())
# Out:
# Missing values before cleaning:
#
# Stock            0
# Oil             10
# EuroToDollar    12
# Gold             0
# dtype: int64

# %%
#Handle missing values
#Forward fill replaces missing values with the previous day's value (preserves time order and avoids using future information)
df_clean = df.ffill()

# %%
#Verifying cleaning
print("\nMissing values after forward fill:\n")
print(df_clean.isna().sum())

#Confirming no missing values remain
print("\nAny missing values remaining?", df_clean.isna().values.any())
# Out:
# Missing values after forward fill:
#
# Stock           0
# Oil             0
# EuroToDollar    0
# Gold            0
# dtype: int64
#
# Any missing values remaining? False

# %%
#Inspecting filled values
#Show rows where missing values originally occurred (helps confirm forward fill worked correctly)
missing_rows = df[df.isna().any(axis=1)]
print("\nRows that originally contained missing values:\n")
print(missing_rows.head())
# Out:
# Rows that originally contained missing values:
#
#                   Stock        Oil  EuroToDollar    Gold
# Date
# 2016-01-18  1916.680054        NaN           NaN  1090.2
# 2016-02-15  1833.400024        NaN           NaN  1234.0
# 2017-01-20  2269.959961  51.450001           NaN  1289.2
# 2017-07-03  2431.389893        NaN        0.8797  1289.9
# 2017-10-09  2551.389893  49.250000           NaN  1362.0

# %% [markdown]
# **Task 3: model construction**
#
# Construct a RNN network that will predict the future value of Stock, one day/time inteval in advance.

# %%
#Creating sequences for RNN input
import numpy as np

#Number of past days used to predict the next day
WINDOW = 10

#Converting time-series data into sequences using previous 'window' days to predict the next value
def create_sequences(X, y, window):
    X_seq, y_seq = [], []

    for i in range(window, len(X)):
        #collect previous 'window' days as input
        X_seq.append(X[i-window:i])

        #target is next day's stock price
        y_seq.append(y[i])

    return np.array(X_seq), np.array(y_seq)

#Creating training and testing sequences
X_train_seq, y_train_seq = create_sequences(X_train.values, y_train.values, WINDOW)
X_test_seq, y_test_seq = create_sequences(X_test.values, y_test.values, WINDOW)

print("Training sequence shape:", X_train_seq.shape)
print("Testing sequence shape:", X_test_seq.shape)
# Out:
# Training sequence shape: (800, 10, 4)
# Testing sequence shape: (193, 10, 4)

# %%
#Building RNN model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, GRU, Dense, Dropout

#Initialising model
model = Sequential()

#Defining input shape 
model.add(Input(shape=(WINDOW, X_train_seq.shape[2])))

#GRU for learning temporal patterns from sequences
model.add(GRU(32))

#Dropout to help reduce overfitting
model.add(Dropout(0.2))

#Output layer for predicting next-day stock price
model.add(Dense(1, activation='linear'))

#Compiling model for regression task
model.compile(
    optimizer='adam',
    loss='mse',
    metrics=['mae']
)

#Displaying model architecture
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ gru_1 (GRU)                          │ (None, 32)                  │           3,648 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,681 (14.38 KB)
#  Trainable params: 3,681 (14.38 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#Training the model
from tensorflow.keras.callbacks import EarlyStopping

#Stopping training if validation performance stops improving
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=25,
    restore_best_weights=True
)

history = model.fit(
    X_train_seq, y_train_seq,
    validation_split=0.2, #using part of training set for validation
    epochs=300,
    batch_size=128,
    shuffle=False, #for time series
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - loss: 0.0017 - mae: 0.0309 - val_loss: 0.0013 - val_mae: 0.0314
# Epoch 2/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0014 - mae: 0.0281 - val_loss: 0.0011 - val_mae: 0.0282
# Epoch 3/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0013 - mae: 0.0270 - val_loss: 8.6473e-04 - val_mae: 0.0221
# Epoch 4/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0013 - mae: 0.0275 - val_loss: 8.9222e-04 - val_mae: 0.0230
# Epoch 5/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0013 - mae: 0.0266 - val_loss: 0.0011 - val_mae: 0.0286
# Epoch 6/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0014 - mae: 0.0279 - val_loss: 9.3338e-04 - val_mae: 0.0242
# Epoch 7/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0013 - mae: 0.0261 - val_loss: 8.6450e-04 - val_mae: 0.0219
# Epoch 8/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0013 - mae: 0.0278 - val_loss: 9.1024e-04 - val_mae: 0.0236
# Epoch 9/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0012 - mae: 0.0259 - val_loss: 9.9777e-04 - val_mae: 0.0260
# Epoch 10/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0013 - mae: 0.0276 - val_loss: 8.9824e-04 - val_mae: 0.0233
# Epoch 11/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0014 - mae: 0.0279 - val_loss: 8.7427e-04 - val_mae: 0.0225
# Epoch 12/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0012 - mae: 0.0265 - val_loss: 9.0466e-04 - val_mae: 0.0234
# Epoch 13/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0013 - mae: 0.0269 - val_loss: 9.4632e-04 - val_mae: 0.0246
# Epoch 14/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0013 - mae: 0.0275 - val_loss: 9.7145e-04 - val_mae: 0.0253
# Epoch 15/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0012 - mae: 0.0263 - val_loss: 9.2380e-04 - val_mae: 0.0240
# Epoch 16/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0012 - mae: 0.0270 - val_loss: 8.7880e-04 - val_mae: 0.0226
# Epoch 17/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0011 - mae: 0.0250 - val_loss: 9.1767e-04 - val_mae: 0.0238
# Epoch 18/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0012 - mae: 0.0270 - val_loss: 9.1136e-04 - val_mae: 0.0236
# Epoch 19/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0011 - mae: 0.0250 - val_loss: 8.8553e-04 - val_mae: 0.0228
# Epoch 20/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0012 - mae: 0.0254 - val_loss: 8.8872e-04 - val_mae: 0.0229
# Epoch 21/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0012 - mae: 0.0258 - val_loss: 9.8525e-04 - val_mae: 0.0256
# Epoch 22/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0012 - mae: 0.0262 - val_loss: 9.3403e-04 - val_mae: 0.0243
# Epoch 23/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0011 - mae: 0.0249 - val_loss: 8.7340e-04 - val_mae: 0.0225
# Epoch 24/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0014 - mae: 0.0287 - val_loss: 8.9259e-04 - val_mae: 0.0231
# Epoch 25/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0013 - mae: 0.0269 - val_loss: 9.1284e-04 - val_mae: 0.0237
# Epoch 26/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0013 - mae: 0.0263 - val_loss: 9.8004e-04 - val_mae: 0.0255
# Epoch 27/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0013 - mae: 0.0270 - val_loss: 9.0680e-04 - val_mae: 0.0236
# Epoch 28/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0012 - mae: 0.0264 - val_loss: 8.6355e-04 - val_mae: 0.0221
# Epoch 29/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0012 - mae: 0.0258 - val_loss: 9.0208e-04 - val_mae: 0.0234
# Epoch 30/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0014 - mae: 0.0277 - val_loss: 9.9724e-04 - val_mae: 0.0259
# Epoch 31/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0012 - mae: 0.0260 - val_loss: 9.7566e-04 - val_mae: 0.0254
# Epoch 32/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0012 - mae: 0.0250 - val_loss: 8.7632e-04 - val_mae: 0.0226
# Epoch 33/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0012 - mae: 0.0263 - val_loss: 8.6001e-04 - val_mae: 0.0219
# Epoch 34/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0012 - mae: 0.0257 - val_loss: 9.2339e-04 - val_mae: 0.0240
# Epoch 35/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0013 - mae: 0.0268 - val_loss: 9.8024e-04 - val_mae: 0.0255
# Epoch 36/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0013 - mae: 0.0263 - val_loss: 8.7215e-04 - val_mae: 0.0225
# Epoch 37/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0012 - mae: 0.0267 - val_loss: 8.6597e-04 - val_mae: 0.0223
# Epoch 38/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0012 - mae: 0.0257 - val_loss: 9.4515e-04 - val_mae: 0.0247
# Epoch 39/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0012 - mae: 0.0260 - val_loss: 9.1421e-04 - val_mae: 0.0239
# Epoch 40/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0011 - mae: 0.0249 - val_loss: 8.5731e-04 - val_mae: 0.0220
# Epoch 41/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0011 - mae: 0.0259 - val_loss: 8.8863e-04 - val_mae: 0.0231
# Epoch 42/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0012 - mae: 0.0263 - val_loss: 9.2340e-04 - val_mae: 0.0241
# Epoch 43/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0012 - mae: 0.0261 - val_loss: 8.9335e-04 - val_mae: 0.0232
# Epoch 44/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0011 - mae: 0.0248 - val_loss: 8.6848e-04 - val_mae: 0.0224
# Epoch 45/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0012 - mae: 0.0254 - val_loss: 9.2774e-04 - val_mae: 0.0242
# Epoch 46/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0012 - mae: 0.0260 - val_loss: 0.0011 - val_mae: 0.0272
# Epoch 47/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0012 - mae: 0.0261 - val_loss: 9.6814e-04 - val_mae: 0.0253
# Epoch 48/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0014 - mae: 0.0270 - val_loss: 8.6803e-04 - val_mae: 0.0225
# Epoch 49/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0011 - mae: 0.0256 - val_loss: 8.9649e-04 - val_mae: 0.0234
# Epoch 50/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0011 - mae: 0.0252 - val_loss: 8.8051e-04 - val_mae: 0.0228
# Epoch 51/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0012 - mae: 0.0252 - val_loss: 9.1721e-04 - val_mae: 0.0239
# Epoch 52/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0012 - mae: 0.0259 - val_loss: 9.4704e-04 - val_mae: 0.0247
# Epoch 53/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0012 - mae: 0.0258 - val_loss: 8.5988e-04 - val_mae: 0.0222
# Epoch 54/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0012 - mae: 0.0265 - val_loss: 8.5707e-04 - val_mae: 0.0219
# Epoch 55/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0012 - mae: 0.0260 - val_loss: 9.4695e-04 - val_mae: 0.0247
# Epoch 56/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0012 - mae: 0.0260 - val_loss: 0.0010 - val_mae: 0.0270
# Epoch 57/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0013 - mae: 0.0262 - val_loss: 8.5986e-04 - val_mae: 0.0221
# Epoch 58/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0013 - mae: 0.0268 - val_loss: 8.6703e-04 - val_mae: 0.0224
# Epoch 59/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0012 - mae: 0.0258 - val_loss: 9.8242e-04 - val_mae: 0.0256
# Epoch 60/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0012 - mae: 0.0261 - val_loss: 9.0223e-04 - val_mae: 0.0235
# Epoch 61/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0011 - mae: 0.0254 - val_loss: 8.7124e-04 - val_mae: 0.0225
# Epoch 62/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0011 - mae: 0.0245 - val_loss: 9.1202e-04 - val_mae: 0.0238
# Epoch 63/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0011 - mae: 0.0250 - val_loss: 8.8178e-04 - val_mae: 0.0229
# Epoch 64/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0013 - mae: 0.0261 - val_loss: 8.7448e-04 - val_mae: 0.0226
# Epoch 65/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0012 - mae: 0.0261 - val_loss: 9.0188e-04 - val_mae: 0.0234
# Epoch 66/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0010 - mae: 0.0239 - val_loss: 9.2639e-04 - val_mae: 0.0241
# Epoch 67/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0011 - mae: 0.0257 - val_loss: 8.8332e-04 - val_mae: 0.0229
# Epoch 68/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0013 - mae: 0.0263 - val_loss: 8.5716e-04 - val_mae: 0.0220
# Epoch 69/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0011 - mae: 0.0256 - val_loss: 8.6685e-04 - val_mae: 0.0224
# Epoch 70/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0011 - mae: 0.0251 - val_loss: 8.6482e-04 - val_mae: 0.0224
# Epoch 71/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0011 - mae: 0.0248 - val_loss: 8.5570e-04 - val_mae: 0.0219
# Epoch 72/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0012 - mae: 0.0256 - val_loss: 8.7071e-04 - val_mae: 0.0225
# Epoch 73/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0011 - mae: 0.0245 - val_loss: 8.9112e-04 - val_mae: 0.0231
# Epoch 74/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0013 - mae: 0.0269 - val_loss: 9.0103e-04 - val_mae: 0.0234
# Epoch 75/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0010 - mae: 0.0240 - val_loss: 8.8942e-04 - val_mae: 0.0231
# Epoch 76/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0011 - mae: 0.0253 - val_loss: 8.7866e-04 - val_mae: 0.0228
# Epoch 77/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0012 - mae: 0.0256 - val_loss: 9.0751e-04 - val_mae: 0.0237
# Epoch 78/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0011 - mae: 0.0247 - val_loss: 9.1001e-04 - val_mae: 0.0238
# Epoch 79/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 9.9205e-04 - mae: 0.0233 - val_loss: 8.8611e-04 - val_mae: 0.0231
# Epoch 80/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 9.7558e-04 - mae: 0.0237 - val_loss: 9.3003e-04 - val_mae: 0.0243
# Epoch 81/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0012 - mae: 0.0249 - val_loss: 8.7201e-04 - val_mae: 0.0226
# Epoch 82/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0011 - mae: 0.0250 - val_loss: 8.5707e-04 - val_mae: 0.0221
# Epoch 83/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0012 - mae: 0.0265 - val_loss: 8.9306e-04 - val_mae: 0.0232
# Epoch 84/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0011 - mae: 0.0252 - val_loss: 8.9559e-04 - val_mae: 0.0233
# Epoch 85/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0011 - mae: 0.0250 - val_loss: 8.6008e-04 - val_mae: 0.0222
# Epoch 86/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0010 - mae: 0.0244 - val_loss: 8.5541e-04 - val_mae: 0.0220
# Epoch 87/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0011 - mae: 0.0251 - val_loss: 9.2592e-04 - val_mae: 0.0242
# Epoch 88/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0011 - mae: 0.0248 - val_loss: 8.9574e-04 - val_mae: 0.0233
# Epoch 89/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0010 - mae: 0.0242 - val_loss: 8.7442e-04 - val_mae: 0.0227
# Epoch 90/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0012 - mae: 0.0254 - val_loss: 8.6395e-04 - val_mae: 0.0223
# Epoch 91/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0012 - mae: 0.0253 - val_loss: 8.8817e-04 - val_mae: 0.0231
# Epoch 92/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0011 - mae: 0.0245 - val_loss: 8.6954e-04 - val_mae: 0.0225
# Epoch 93/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0011 - mae: 0.0248 - val_loss: 8.5576e-04 - val_mae: 0.0219
# Epoch 94/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0013 - mae: 0.0267 - val_loss: 8.5595e-04 - val_mae: 0.0219
# Epoch 95/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0010 - mae: 0.0243 - val_loss: 8.6663e-04 - val_mae: 0.0224
# Epoch 96/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0011 - mae: 0.0251 - val_loss: 8.7929e-04 - val_mae: 0.0228
# Epoch 97/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0011 - mae: 0.0239 - val_loss: 8.8345e-04 - val_mae: 0.0229
# Epoch 98/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0010 - mae: 0.0246 - val_loss: 8.6862e-04 - val_mae: 0.0225
# Epoch 99/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0012 - mae: 0.0248 - val_loss: 8.6312e-04 - val_mae: 0.0224
# Epoch 100/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0011 - mae: 0.0251 - val_loss: 9.0641e-04 - val_mae: 0.0237
# Epoch 101/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 9.5739e-04 - mae: 0.0231 - val_loss: 8.7180e-04 - val_mae: 0.0226
# Epoch 102/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0011 - mae: 0.0246 - val_loss: 8.6965e-04 - val_mae: 0.0226
# Epoch 103/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0012 - mae: 0.0251 - val_loss: 9.0466e-04 - val_mae: 0.0236
# Epoch 104/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0011 - mae: 0.0255 - val_loss: 9.2742e-04 - val_mae: 0.0243
# Epoch 105/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 9.5648e-04 - mae: 0.0235 - val_loss: 8.7418e-04 - val_mae: 0.0227
# Epoch 106/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0011 - mae: 0.0243 - val_loss: 9.1571e-04 - val_mae: 0.0240
# Epoch 107/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0011 - mae: 0.0239 - val_loss: 9.1590e-04 - val_mae: 0.0241
# Epoch 108/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 9.9584e-04 - mae: 0.0235 - val_loss: 8.5314e-04 - val_mae: 0.0221
# Epoch 109/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0012 - mae: 0.0254 - val_loss: 8.9696e-04 - val_mae: 0.0235
# Epoch 110/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0011 - mae: 0.0249 - val_loss: 8.7142e-04 - val_mae: 0.0227
# Epoch 111/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0012 - mae: 0.0251 - val_loss: 8.4973e-04 - val_mae: 0.0219
# Epoch 112/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0011 - mae: 0.0245 - val_loss: 8.4927e-04 - val_mae: 0.0218
# Epoch 113/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0011 - mae: 0.0242 - val_loss: 8.6647e-04 - val_mae: 0.0225
# Epoch 114/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0010 - mae: 0.0232 - val_loss: 8.5363e-04 - val_mae: 0.0221
# Epoch 115/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0010 - mae: 0.0235 - val_loss: 8.8074e-04 - val_mae: 0.0230
# Epoch 116/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 9.1621e-04 - mae: 0.0225 - val_loss: 9.1511e-04 - val_mae: 0.0240
# Epoch 117/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0012 - mae: 0.0250 - val_loss: 8.6338e-04 - val_mae: 0.0225
# Epoch 118/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0012 - mae: 0.0254 - val_loss: 8.7153e-04 - val_mae: 0.0227
# Epoch 119/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0010 - mae: 0.0239 - val_loss: 9.1983e-04 - val_mae: 0.0241
# Epoch 120/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0011 - mae: 0.0244 - val_loss: 9.2395e-04 - val_mae: 0.0242
# Epoch 121/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0011 - mae: 0.0236 - val_loss: 8.8375e-04 - val_mae: 0.0231
# Epoch 122/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 9.8899e-04 - mae: 0.0240 - val_loss: 8.9032e-04 - val_mae: 0.0234
# Epoch 123/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0010 - mae: 0.0241 - val_loss: 8.8572e-04 - val_mae: 0.0232
# Epoch 124/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0011 - mae: 0.0244 - val_loss: 8.7001e-04 - val_mae: 0.0227
# Epoch 125/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0012 - mae: 0.0266 - val_loss: 8.4537e-04 - val_mae: 0.0218
# Epoch 126/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0011 - mae: 0.0251 - val_loss: 8.4701e-04 - val_mae: 0.0218
# Epoch 127/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0012 - mae: 0.0245 - val_loss: 8.7382e-04 - val_mae: 0.0227
# Epoch 128/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0010 - mae: 0.0240 - val_loss: 8.7230e-04 - val_mae: 0.0227
# Epoch 129/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 9.9310e-04 - mae: 0.0236 - val_loss: 8.7227e-04 - val_mae: 0.0227
# Epoch 130/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0012 - mae: 0.0243 - val_loss: 8.6742e-04 - val_mae: 0.0226
# Epoch 131/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 9.8811e-04 - mae: 0.0228 - val_loss: 8.6838e-04 - val_mae: 0.0227
# Epoch 132/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0011 - mae: 0.0251 - val_loss: 8.4567e-04 - val_mae: 0.0219
# Epoch 133/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 9.7017e-04 - mae: 0.0241 - val_loss: 8.4774e-04 - val_mae: 0.0219
# Epoch 134/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 9.1344e-04 - mae: 0.0223 - val_loss: 9.2337e-04 - val_mae: 0.0242
# Epoch 135/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0010 - mae: 0.0241 - val_loss: 8.7006e-04 - val_mae: 0.0226
# Epoch 136/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0011 - mae: 0.0243 - val_loss: 8.4650e-04 - val_mae: 0.0218
# Epoch 137/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 9.1995e-04 - mae: 0.0230 - val_loss: 8.6446e-04 - val_mae: 0.0225
# Epoch 138/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 9.1953e-04 - mae: 0.0233 - val_loss: 9.0394e-04 - val_mae: 0.0237
# Epoch 139/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0011 - mae: 0.0240 - val_loss: 8.5585e-04 - val_mae: 0.0222
# Epoch 140/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0010 - mae: 0.0241 - val_loss: 8.5480e-04 - val_mae: 0.0221
# Epoch 141/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0011 - mae: 0.0240 - val_loss: 8.7229e-04 - val_mae: 0.0226
# Epoch 142/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0010 - mae: 0.0243 - val_loss: 8.6844e-04 - val_mae: 0.0225
# Epoch 143/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0011 - mae: 0.0238 - val_loss: 8.5979e-04 - val_mae: 0.0222
# Epoch 144/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 9.1113e-04 - mae: 0.0226 - val_loss: 8.5669e-04 - val_mae: 0.0221
# Epoch 145/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 9.6097e-04 - mae: 0.0233 - val_loss: 8.7414e-04 - val_mae: 0.0227
# Epoch 146/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 9.1854e-04 - mae: 0.0229 - val_loss: 8.6669e-04 - val_mae: 0.0224
# Epoch 147/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 9.6641e-04 - mae: 0.0230 - val_loss: 8.5655e-04 - val_mae: 0.0220
# Epoch 148/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 8.5910e-04 - mae: 0.0221 - val_loss: 8.6637e-04 - val_mae: 0.0224
# Epoch 149/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 9.7837e-04 - mae: 0.0230 - val_loss: 8.8122e-04 - val_mae: 0.0228
# Epoch 150/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 8.7683e-04 - mae: 0.0227 - val_loss: 8.6978e-04 - val_mae: 0.0225

# %%
#Plotting training performance
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')

plt.title('Training vs Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# **Task 4: test**
#
# Evaluate the model on the test set and display any change in accuracy over time, if any. Test for common issues found in deep learning models.

# %%
#Generating predcitions
#Predicting on training sequences
train_predictions = model.predict(X_train_seq)

#Predicting on test sequences
test_predictions = model.predict(X_test_seq)

#Flattening arrays for easier comparison
train_predictions = train_predictions.flatten()
test_predictions = test_predictions.flatten()

#Actual values
train_actual = y_train_seq.flatten()
test_actual = y_test_seq.flatten()
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step

# %%
#Calculating error metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

#Root Mean Squared Error (sensitive to large errors)
train_rmse = np.sqrt(mean_squared_error(train_actual, train_predictions))
test_rmse = np.sqrt(mean_squared_error(test_actual, test_predictions))

#Mean Absolute Error (average error)
train_mae = mean_absolute_error(train_actual, train_predictions)
test_mae = mean_absolute_error(test_actual, test_predictions)

print("Training RMSE:", train_rmse)
print("Testing RMSE:", test_rmse)

print("\nTraining MAE:", train_mae)
print("Testing MAE:", test_mae)
# Out:
# Training RMSE: 0.020232342715412428
# Testing RMSE: 0.023703146546937785
#
# Training MAE: 0.014245319143426633
# Testing MAE: 0.019420176069398293

# %%
#Comparing with naive baseline (tomorrow = today)
#shifting actual values by 1 day
naive_pred = test_actual[:-1]
naive_actual = test_actual[1:]

naive_rmse = np.sqrt(mean_squared_error(naive_actual, naive_pred))

print("\nNaive baseline RMSE:", naive_rmse)
# Out:
# Naive baseline RMSE: 0.014421401030477263

# %%
#Accuracy over time (rolling error)
import pandas as pd
import matplotlib.pyplot as plt

#Absolute error over time
errors = np.abs(test_actual - test_predictions)

#30-day rolling mean error
rolling_error = pd.Series(errors).rolling(window=30).mean()

plt.figure(figsize=(10,4))
plt.plot(rolling_error)
plt.title("Prediction Error Over Time (Rolling MAE)")
plt.xlabel("Time")
plt.ylabel("Error")
plt.show()

# %%
#Actual vs Predicted Plot
plt.figure(figsize=(10,5))

plt.plot(test_actual, label="Actual")
plt.plot(test_predictions, label="Predicted")

plt.title("Actual vs Predicted Stock Prices")
plt.legend()
plt.show()

# %%
#Residual Distribution (bias check)
residuals = test_actual - test_predictions

plt.figure(figsize=(6,4))
plt.hist(residuals, bins=30)
plt.title("Prediction Error Distribution")
plt.xlabel("Error")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Post (complete by Sunday Week 3)
#
# Please upload your code for Tasks 1-4 to the group locker by Sunday if possible. The implementation does not need to be complete and you can continue to upload improved versions. The link is below. To organise things well; create a new subfolder in the locker for your work. You can upload multiple copies with different filenames to archive development stages. Post the link to the forum/topic. The purpose is to get feedback from others in the group, so if you have only a basic outline then you may get ideas about how to proceed and also examples from others in your group.
#
# Post the location to the appropriate forum/topic.
#
# No posts should reference Task 5.

# %% [markdown]
# ### Respond (complete by Wednesday Week 4)
#
# If you feel you can provide useful advise then respond to another member of the group through the appropriate forum. Responses should be respectful and offer some sort of advise. Try and avoid clogging the forums with support or thank you messages.
#
# In reviewing others code you will discover different ways to tackle the same problem. It is acceptable to copy parts of others code. However whole scale copying from another notebook is not acceptable.

# %% [markdown]
# The group interaction forms part of the overall assessment. Grading guidelines for the forum posts: the rubrics for the e-tivity are here
# https://learn.ul.ie/d2l/lp/rubrics/preview.d2l?ou=73310&rubricId=4446&originTool=quicklinks

# %% [markdown]
# <a id='part2'></a>
# ## Sentiment Analysis
#
#
# This task is a individual task and should **not** to be uploaded to the Group Locker. No posts should be given via the forums. Marks will be deducted if the instructions are not followed (see rubrics). This part should be uploaded directly to Brightpsace.
#
# ### Context
#
# You have a model that predicts the sentiment of a film review (positive or negative) from the IMDB. There are two hyperparameters that format the data from IMDB: the maximum review length and the dictionary size. Below is a RNN model that predicts sentiment values.
#
#
# ### Task 5:  (completed by Sunday Week 4)
#
# Keeping top_words, max_review_lenngth and the embedding_vector_length the same, change the model so that it uses attention only, i.e. there are no recurrent components. The only Keras layers (defined here https://www.tensorflow.org/api_docs/python/tf/keras/layers) that you allowed to use are:
# - Input,
# - Embedding,
# - Dense,
# - Any Attention (must be at leat one),
# - TimeDistributed,
# - Any Merging,
# - Any Reshaping,
# - Any Pooling,
# - Dropout.
#
# You need not use any of the layers (except attention) but you can use some more than once. Can you do at least as good as the RNN example?
#
# **NB** There are many examples of using attention for sentiment analysis but we looking to see if you can construct a sensible model. The model will be delibrately restricted, so do not waste too much time achieving spectacular accuracy. Remember the rules of thumb that we discussed in the Introduction to DL module.

# %%
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Embedding, Dense, Dropout,
    MultiHeadAttention, Add,
    TimeDistributed, GlobalAveragePooling1D
)
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model

import matplotlib.pyplot as plt
import numpy as np

top_words = 100
(Rev_train, Sc_train), (Rev_test, Sc_test) = imdb.load_data(num_words=top_words)

max_review_length = 500
X_train = sequence.pad_sequences(Rev_train, maxlen=max_review_length)
X_test = sequence.pad_sequences(Rev_test, maxlen=max_review_length)
print(X_train.shape)

embedding_vector_length = 16
# Out:
# (25000, 500)

# %%
#Input is a sequence of word IDs (integers)
inp = Input(shape=(max_review_length,), name="review_tokens")

#Turning tokens into embedding vectors
x = Embedding(top_words, embedding_vector_length, name="embedding")(inp)
x = Dropout(0.2, name="embed_dropout")(x)

#Small feature projection per time step (helps attention learn richer patterns)
#TimeDistributed applies the same Dense layer to each timestep
x_proj = TimeDistributed(Dense(embedding_vector_length, activation="relu"), name="td_dense")(x)

#Self-attention: query=key=value=x_proj (each token attends to all tokens)
attn = MultiHeadAttention(
    num_heads=2,
    key_dim=embedding_vector_length,
    dropout=0.1,
    name="self_attention"
)(x_proj, x_proj)

#Residual connection to help training stability
x_res = Add(name="residual_add")([x_proj, attn])

#Pooling the sequence into one vector (simple and effective for sentiment)
x_pool = GlobalAveragePooling1D(name="avg_pool")(x_res)

#Small dropout before final decision
x_pool = Dropout(0.2, name="final_dropout")(x_pool)

#Output probability of positive sentiment
out = Dense(1, activation="sigmoid", name="sentiment")(x_pool)

model_att = Model(inputs=inp, outputs=out, name="IMDB_AttentionOnly")

model_att.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=["accuracy"]
)

print(model_att.summary())
plot_model(model_att, show_shapes=True)
# Out:
# Model: "IMDB_AttentionOnly"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ review_tokens (InputLayer)    │ (None, 500)               │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ embedding (Embedding)         │ (None, 500, 16)           │           1,600 │ review_tokens[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ embed_dropout (Dropout)       │ (None, 500, 16)           │               0 │ embedding[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ td_dense (TimeDistributed)    │ (None, 500, 16)           │             272 │ embed_dropout[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ self_attention                │ (None, 500, 16)           │           2,160 │ td_dense[0][0],            │
# │ (MultiHeadAttention)          │                           │                 │ td_dense[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ residual_add (Add)            │ (None, 500, 16)           │               0 │ td_dense[0][0],            │
# │                               │                           │                 │ self_attention[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ avg_pool                      │ (None, 16)                │               0 │ residual_add[0][0]         │
# │ (GlobalAveragePooling1D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ final_dropout (Dropout)       │ (None, 16)                │               0 │ avg_pool[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ sentiment (Dense)             │ (None, 1)                 │              17 │ final_dropout[0][0]        │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 4,049 (15.82 KB)
#  Trainable params: 4,049 (15.82 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# You must install pydot (`pip install pydot`) for `plot_model` to work.

# %%
#Training (for good practice: early stopping)
nepoch_att = 50  
early_stop = EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True
)

history_att = model_att.fit(
    X_train, Sc_train,
    validation_data=(X_test, Sc_test),
    epochs=nepoch_att,
    batch_size=128,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 370s 2s/step - accuracy: 0.5544 - loss: 0.6813 - val_accuracy: 0.6896 - val_loss: 0.5930
# Epoch 2/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 282s 1s/step - accuracy: 0.7049 - loss: 0.5693 - val_accuracy: 0.7081 - val_loss: 0.5564
# Epoch 3/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 287s 1s/step - accuracy: 0.7212 - loss: 0.5517 - val_accuracy: 0.7221 - val_loss: 0.5410
# Epoch 4/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 308s 2s/step - accuracy: 0.7244 - loss: 0.5470 - val_accuracy: 0.7289 - val_loss: 0.5367
# Epoch 5/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 283s 1s/step - accuracy: 0.7215 - loss: 0.5459 - val_accuracy: 0.7274 - val_loss: 0.5367
# Epoch 6/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 283s 1s/step - accuracy: 0.7258 - loss: 0.5409 - val_accuracy: 0.7300 - val_loss: 0.5351
# Epoch 7/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 286s 1s/step - accuracy: 0.7259 - loss: 0.5413 - val_accuracy: 0.7293 - val_loss: 0.5365
# Epoch 8/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 282s 1s/step - accuracy: 0.7236 - loss: 0.5426 - val_accuracy: 0.7298 - val_loss: 0.5335
# Epoch 9/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 285s 1s/step - accuracy: 0.7266 - loss: 0.5418 - val_accuracy: 0.7330 - val_loss: 0.5326
# Epoch 10/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 283s 1s/step - accuracy: 0.7264 - loss: 0.5411 - val_accuracy: 0.7280 - val_loss: 0.5383
# Epoch 11/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 284s 1s/step - accuracy: 0.7290 - loss: 0.5401 - val_accuracy: 0.7315 - val_loss: 0.5320
# Epoch 12/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 279s 1s/step - accuracy: 0.7269 - loss: 0.5414 - val_accuracy: 0.7278 - val_loss: 0.5343
# Epoch 13/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 285s 1s/step - accuracy: 0.7282 - loss: 0.5424 - val_accuracy: 0.7255 - val_loss: 0.5366
# Epoch 14/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 286s 1s/step - accuracy: 0.7288 - loss: 0.5410 - val_accuracy: 0.7303 - val_loss: 0.5313
# Epoch 15/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 285s 1s/step - accuracy: 0.7272 - loss: 0.5410 - val_accuracy: 0.7243 - val_loss: 0.5381
# Epoch 16/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 288s 1s/step - accuracy: 0.7267 - loss: 0.5417 - val_accuracy: 0.7314 - val_loss: 0.5296
# Epoch 17/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 280s 1s/step - accuracy: 0.7296 - loss: 0.5369 - val_accuracy: 0.7326 - val_loss: 0.5309
# Epoch 18/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 283s 1s/step - accuracy: 0.7272 - loss: 0.5390 - val_accuracy: 0.7197 - val_loss: 0.5435
# Epoch 19/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 287s 1s/step - accuracy: 0.7309 - loss: 0.5363 - val_accuracy: 0.7292 - val_loss: 0.5355
# Epoch 20/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 262s 1s/step - accuracy: 0.7290 - loss: 0.5378 - val_accuracy: 0.7304 - val_loss: 0.5307
# Epoch 21/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 207s 1s/step - accuracy: 0.7289 - loss: 0.5380 - val_accuracy: 0.7236 - val_loss: 0.5379

# %%
#Test Evaluation
test_loss, test_acc = model_att.evaluate(X_test, Sc_test, verbose=0)
print(f"\nAttention-only model test accuracy: {test_acc:.4f}")
print(f"Attention-only model test loss:     {test_loss:.4f}")
# Out:
# Attention-only model test accuracy: 0.7314
# Attention-only model test loss:     0.5296

# %%
#Plotting (Training Curves for attention model)
plt.figure(figsize=(8,4))
plt.plot(history_att.history["loss"], label="Train Loss")
plt.plot(history_att.history["val_loss"], label="Val Loss")
plt.title("Attention-only Model Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

plt.figure(figsize=(8,4))
plt.plot(history_att.history["accuracy"], label="Train Acc")
plt.plot(history_att.history["val_accuracy"], label="Val Acc")
plt.title("Attention-only Model Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
#Comparing against saved RNN history 
nepoch_rnn = 150
try:
    IMDB_history = np.load("IMDBTrainhist.npy", allow_pickle=True).item()

    plt.figure(figsize=(8,4))
    plt.plot(range(nepoch_rnn), IMDB_history.history["val_accuracy"], label="RNN Val Acc (saved)")
    plt.plot(range(len(history_att.history["val_accuracy"])), history_att.history["val_accuracy"], label="Attention Val Acc")
    plt.title("Validation Accuracy: RNN (saved) vs Attention-only")
    plt.xlabel("Epoch")
    plt.ylabel("Val Accuracy")
    plt.legend()
    plt.show()

except FileNotFoundError:
    print("\nIMDBTrainhist.npy not found, skipping RNN comparison plot.")

# %% [markdown]
# The history for the model above has been saved, as it takes a while to run. If you want to run it yourself then comment out the second line.

# %% [markdown]
# ### Final Submission (complete by Sunday Week 4)
#
# Submit Tasks 1-5 in a single notebook this before the deadline on Sunday.

# %% [raw]
# ## Reflection
#
# There are no specific marks allocated for a reflection. However due consideration will be given if pertinent comments or valuable insights are made.

# %% [markdown]
# ### Task 1:
#
# For Task 1, I prepared the stock dataset so it could be used with a neural network.
#
# I first loaded the data and set the Date column as the index to keep the time order intact, since this is time-series data. The dataset contains 1,033 daily records with four variables: Stock, Oil, Gold and EuroToDollar. I checked the dataset structure and confirmed that all variables are numeric. I also noticed a small number of missing values in the Oil and EuroToDollar columns, which I will address in the data cleaning step.
#
# To make the data suitable for a neural network, I normalised the values using MinMax scaling so that all inputs are on a similar scale.
#
# Because the goal is to predict the stock price one day ahead, I created a target variable by shifting the Stock column forward by one day. The final row was removed because it does not have a future value to predict.
#
# Finally, I split the dataset chronologically to preserve the time sequence:
#
# 80% training data (810 samples)
#
# 20% testing data (203 samples)
#
# This produced a training set with four input features and a target value representing the next day’s stock price, ready for modelling in the next task.

# %% [markdown]
# ### Task 2:
#
# For Task 2, I cleaned the dataset by addressing the missing values identified in the Oil and EuroToDollar columns. Before cleaning, there were 10 missing values in Oil and 12 in EuroToDollar.
#
# Because this is time-series financial data, it was important to preserve the time sequence when handling missing values. I used forward fill, which replaces missing entries with the previous day’s value. This method is appropriate because financial prices typically change gradually and it avoids introducing future information into the dataset.
#
# After applying forward fill, I verified that no missing values remained. I also inspected several of the rows that originally contained missing values to confirm that the gaps were filled correctly and that the timeline remained intact.
#
# I did not remove any rows, as doing so could disrupt the time continuity of the data. The dataset is now complete and suitable for training the neural network.

# %% [markdown]
# ### Task 3:
#
# For Task 3, I built a recurrent neural network to predict the stock price one day ahead. Since stock prices depend on recent trends rather than a single observation, I created sliding windows using the previous 10 days of data so the model could learn temporal patterns.
#
# I used a GRU layer because it is well suited to time-series forecasting and can capture relationships across time efficiently. A dropout layer was included to reduce overfitting, and a dense output layer produces the predicted stock value for the next day.
#
# The model was trained without shuffling the data to preserve time order, and early stopping was used to prevent overtraining. The training and validation loss both decreased over time and remained close together, indicating that the model learned meaningful patterns and generalised well without significant overfitting.

# %% [markdown]
# ### Task 4:
#
# For Task 4, I evaluated the trained model using the unseen test data to assess how accurately it predicts stock prices one day ahead. I compared the predicted values with the actual values using RMSE and MAE, and also compared performance with a naive baseline that assumes tomorrow’s price will be the same as today’s.
#
# The model produced low prediction errors, and the test error was only slightly higher than the training error, indicating good generalisation and no significant overfitting. Although the naive baseline achieved a slightly lower RMSE, this is common in financial time series because stock prices are highly autocorrelated. Despite this, the RNN was able to capture broader temporal patterns and follow overall trends.
#
# The rolling error plot showed that prediction accuracy remained relatively stable over time, with only minor fluctuations. The actual vs predicted plot demonstrated that the model closely followed the overall trend, with small deviations during sharper movements. The error distribution was centred around zero, indicating no systematic bias in the predictions.
#
# Overall, the model performs consistently and generalises well, with no major deep learning issues such as overfitting, instability, or bias detected.

# %% [markdown]
# ## Task 5:
#
# For Task 5, I replaced the LSTM-based model with an attention-only architecture while keeping the same data formatting and hyperparameters. Instead of processing the review sequentially, the self-attention layer allows the model to focus on the most relevant words by learning relationships between tokens across the entire review.
#
# One challenge was understanding how to structure the model without using any recurrent layers while still capturing context. Using self-attention with pooling helped summarise the sequence effectively, and adding a residual connection improved training stability.
#
# Training converged quickly and early stopping prevented unnecessary extra epochs. The model achieved a test accuracy of approximately 73%, which is competitive given the restricted architecture. While the original RNN reached slightly higher peak accuracy, the attention model performed well and learned meaningful patterns efficiently.
#
# Overall, this task helped me understand how attention mechanisms can capture context in text data without relying on recurrent networks.
